# %%
import codecs
import numpy as np
import pandas
import random
import sys
from janome.tokenizer import Tokenizer
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers.embeddings import Embedding
# %matplotlib notebook
import matplotlib.pyplot as plt


# セリフデータを読み込みます
types = ["cute","cool","passion"]

def get_words(type_temp):
    serif_all = []
    name_all = []
    filename = "./data/comment_"+type_temp+".txt"
    file = codecs.open(filename, 'r')
    serif_all.extend(file.readlines())
    file.close()
    filename = "./data/name_"+type_temp+".txt"
    file = codecs.open(filename,"r")
    name_all.extend(file.readlines())
    file.close()
    # 品詞分解し全ての単語と登場回数を収集します
    words = []
    t = Tokenizer()
    counter = 0
    for serif in serif_all:
        counter += 1
        print(counter,end = "\r")
        serif = serif.replace('\n', '')
        tokens = t.tokenize(serif)#品詞ごとに分解される

        for j in range(0,len(tokens)): #すべての単語についてみていく
            token = tokens[j]#ある単語に注目
            is_new_word = True
            for i in range(len(words)):#既出単語と比較し、tokenが既出か確認
                if words[i][0] == token.surface and words[i][1] == token.part_of_speech[:2]:#tokenの単語そのものと品詞が一致していたら既出とみなす
                    words[i][2] += 1#出現回数を増やす
                    is_new_word = False
                    break
            if is_new_word:#新出単語であれば
                words.append([token.surface, token.part_of_speech[:2], 1])#wordsに記録、part_of_speech[:2]になっているのはpart_of_speechが"名詞,一般,*,*"のような文字列になっているから"
    # 単語情報をデータフレームに変換します
    dic = pandas.DataFrame(words)
    dic.columns = ['words', 'parts', 'freq']
    dic = dic.sort_values(by=['freq'], ascending=False)
    dic = dic.reset_index(drop=True)#出現回数の降順にインデックスを付け直す
    num_words = dic.shape[0] # 全単語数を確認しておきます
    return dic
dic = {}
for type_temp in types:
    dic[type_temp] = get_words(type_temp)
print(dic)
# Out:
# {'cute':         words parts  freq
# 0           、    記号  2810
# 1           ！    記号  1506
# 2           …    記号  1466
# 3           て    助詞  1339
# 4           の    助詞  1301
# 5           に    助詞  1205
# 6           。    記号   940
# 7           ○    記号   813
# 8                記号   776
# 9           は    助詞   771
# 10         です    助動   744
# 11          た    助動   684
# 12          ？    記号   614
# 13          を    助詞   611
# 14          が    助詞   593
# 15          も    助詞   584
# 16          で    助詞   544
# 17          し    動詞   478
# 18          ー    名詞   465
# 19          ♪    名詞   434
# 20          ね    助詞   429
# 21         ます    助動   412
# 22          だ    助動   409
# 23          よ    助詞   391
# 24         さん    名詞   379
# 25          ん    名詞   369
# 26          と    助詞   367
# 27         から    助詞   359
# 28          か    助詞   344
# 29          な    助動   324
# ...       ...   ...   ...
# 5015      そりゃ    接続     1
# 5016       懐い    動詞     1
# 5017       使お    動詞     1
# 5018       おい    感動     1
# 5019     ニヤニヤ    副詞     1
# 5020       すん    動詞     1
# 5021      はさみ    動詞     1
# 5022     シンバル    名詞     1
# 5023       視点    名詞     1
# 5024     ちびっこ    名詞     1
# 5025        釘    名詞     1
# 5026       づけ    動詞     1
# 5027      まわり    名詞     1
# 5028       男子    名詞     1
# 5029      ピラリ    名詞     1
# 5030     着替える    動詞     1
# 5031      かかる    動詞     1
# 5032       きち    名詞     1
# 5033    ゃったぽよ    名詞     1
# 5034  リナリナサンタ    名詞     1
# 5035        布    名詞     1
# 5036      少なめ    名詞     1
# 5037   バージョーン    名詞     1
# 5038       ハデ    名詞     1
# 5039        訳    名詞     1
# 5040       ヘリ    名詞     1
# 5041      負ける    動詞     1
# 5042       しょ    名詞     1
# 5043  ホーリーナイト    名詞     1
# 5044      なので    接続     1
#
# [5045 rows x 3 columns], 'cool':       words parts  freq
# 0         …    記号  2781
# 1         、    記号  2688
# 2         。    記号  1785
# 3         の    助詞  1416
# 4         て    助詞  1392
# 5         に    助詞  1221
# 6         は    助詞   987
# 7         ！    記号   909
# 8         ○    記号   800
# 9         を    助詞   766
# 10        が    助詞   742
# 11        た    助動   730
# 12        私    名詞   598
# 13        も    助詞   587
# 14        ？    記号   586
# 15       です    助動   583
# 16             記号   512
# 17        で    助詞   503
# 18        ね    助詞   488
# 19        と    助詞   478
# 20        し    動詞   452
# 21        な    助動   414
# 22        よ    助詞   408
# 23        か    助詞   401
# 24       ない    助動   379
# 25        だ    助動   374
# 26       ます    助動   372
# 27       から    助詞   369
# 28       さん    名詞   315
# 29        ん    名詞   299
# ...     ...   ...   ...
# 5015     ピラ    名詞     1
# 5016      ン    名詞     1
# 5017     コス    名詞     1
# 5018     プレ    名詞     1
# 5019    フツウ    名詞     1
# 5020    っしょ    助動     1
# 5021    ギャル    名詞     1
# 5022    あくび    名詞     1
# 5023   巡り合わ    動詞     1
# 5024    ひつじ    名詞     1
# 5025     泰葉    名詞     1
# 5026    まえる    動詞     1
# 5027   ふわふわ    副詞     1
# 5028     こも    動詞     1
# 5029      似    動詞     1
# 5030     求め    名詞     1
# 5031     必然    名詞     1
# 5032     異国    名詞     1
# 5033    眺めよ    動詞     1
# 5034   ストップ    名詞     1
# 5035   出会える    動詞     1
# 5036     広げ    動詞     1
# 5037     別れ    名詞     1
# 5038   あいさつ    名詞     1
# 5039     出す    動詞     1
# 5040     特性    名詞     1
# 5041     にく    形容     1
# 5042    きゅう    名詞     1
# 5043  がんばれる    動詞     1
# 5044   クイーン    名詞     1
#
# [5045 rows x 3 columns], 'passion':            words parts  freq
# 0              、    記号  2704
# 1              ！    記号  2386
# 2              の    助詞  1370
# 3              て    助詞  1237
# 4              に    助詞  1108
# 5                   記号  1047
# 6              ○    記号   867
# 7              は    助詞   863
# 8              …    記号   816
# 9              。    記号   738
# 10             も    助詞   662
# 11             が    助詞   640
# 12             ？    記号   616
# 13             で    助詞   616
# 14             ー    名詞   595
# 15             を    助詞   572
# 16             た    助動   570
# 17             だ    助動   568
# 18             よ    助詞   528
# 19             ね    助詞   471
# 20             と    助詞   451
# 21             し    動詞   442
# 22            です    助動   412
# 23            から    助詞   387
# 24             ん    名詞   380
# 25             な    助動   379
# 26             ♪    名詞   353
# 27             っ    動詞   307
# 28             か    助詞   301
# 29            ない    助動   292
# ...          ...   ...   ...
# 5586         おもろ    形容     1
# 5587           譜    名詞     1
# 5588         受かる    動詞     1
# 5589     オーディション    名詞     1
# 5590         っきり    名詞     1
# 5591          いよ    名詞     1
# 5592       キターーッ    名詞     1
# 5593  ストラーイクーーーッ    名詞     1
# 5594          かれ    動詞     1
# 5595          だか    動詞     1
# 5596        トランプ    名詞     1
# 5597        引き分け    名詞     1
# 5598       ートランプ    名詞     1
# 5599     スイーツバディ    名詞     1
# 5600         中学生    名詞     1
# 5601        クギヅケ    名詞     1
# 5602          うま    形容     1
# 5603         ひな壇    名詞     1
# 5604       飾り付けよ    動詞     1
# 5605         サボっ    動詞     1
# 5606         お雛様    名詞     1
# 5607         内裏様    名詞     1
# 5608           完    名詞     1
# 5609          ペキ    名詞     1
# 5610          ソコ    名詞     1
# 5611         スゴク    名詞     1
# 5612         目当て    名詞     1
# 5613          宣言    名詞     1
# 5614         目指さ    動詞     1
# 5615         励まし    動詞     1
#
# [5616 rows x 3 columns]}

# %%
def get_density(type_temp,feature_words):
    serif_all = []
    name_all = []
    filename = "./data/comment_"+type_temp+".txt"
    file = codecs.open(filename, 'r')
    serif_all.extend(file.readlines())
    file.close()
    filename = "./data/name_"+type_temp+".txt"
    file = codecs.open(filename,"r")
    name_all.extend(file.readlines())
    file.close()
    # 品詞分解し全ての単語と登場回数を収集します
    density_temp = [[] for i in range(len(serif_all))]#!と…の密度を計算
    t = Tokenizer()
    counter = 0
    counter_feature = {}
    for serif in serif_all:
        for feature in feature_words:
            counter_feature[feature] = 0
        serif = serif.replace('\n', '')
        tokens = t.tokenize(serif)#品詞ごとに分解される
        for j in range(0,len(tokens)): #すべての単語についてみていく
            token = tokens[j]#ある単語に注目
            for feature in feature_words:
                if token.surface == feature:
                    counter_feature[feature] += 1
        for feature in feature_words:
            density_temp[counter].append(counter_feature[feature]/len(tokens))
        counter += 1
        print(counter,end = "\r")
    return density_temp
feature_words = ["！","…","ー","♪"]
density = {}
for type_temp in types:
    density[type_temp] = np.array(get_density(type_temp,feature_words))
print(feature_words)
for type_temp in types:
    print(type_temp)
    print(density[type_temp])
# Out:
# ['！', '…', 'ー', '♪']
# cute
# [[0.05555556 0.         0.         0.02777778]
#  [0.03030303 0.         0.         0.03030303]
#  [0.15555556 0.04444444 0.         0.        ]
#  ...
#  [0.         0.02380952 0.02380952 0.07142857]
#  [0.         0.05769231 0.         0.        ]
#  [0.         0.02040816 0.         0.        ]]
# cool
# [[0.         0.11111111 0.         0.        ]
#  [0.         0.04166667 0.         0.        ]
#  [0.         0.         0.         0.        ]
#  ...
#  [0.         0.32142857 0.         0.        ]
#  [0.         0.05555556 0.         0.        ]
#  [0.06896552 0.05172414 0.         0.        ]]
# passion
# [[0.05263158 0.         0.05263158 0.02631579]
#  [0.08       0.         0.02       0.02      ]
#  [0.         0.         0.         0.        ]
#  ...
#  [0.03773585 0.03773585 0.         0.        ]
#  [0.06521739 0.         0.         0.        ]
#  [0.125      0.         0.         0.        ]]

# %%
colors = {"cute":"magenta","cool":"blue","passion":"yellow"}
from pylab import rcParams
for type_temp in types:
    plt.scatter(density[type_temp][:,1],density[type_temp][:,2],color = colors[type_temp],label = type_temp,s = 5.0)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#3次元プロットするためのモジュール
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook
#グラフの枠を作っていく
fig = plt.figure()
ax = Axes3D(fig)
#軸にラベルを付けたいときは書く
ax.set_xlabel(feature_words[0])
ax.set_ylabel(feature_words[1])
ax.set_zlabel(feature_words[2])
for type_temp in types:
    ax.plot(density[type_temp][:,0],density[type_temp][:,1],density[type_temp][:,2],marker = "o",color = colors[type_temp],label = type_temp,linestyle = "None",ms = 4)
plt.legend()
plt.savefig("feature.jpg")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import sklearn.model_selection
densities = []
target = []
for type_temp in types:
    for density_temp in density[type_temp]:
        densities.append(density_temp)
        target.append(type_temp)
densities = np.array(densities)
target = np.array(target)
print(densities)
print(target)
print(len(densities),len(target))
train_x, test_x, train_y, test_y = sklearn.model_selection.train_test_split(densities, target, test_size=0.2)
import sklearn.ensemble
rf = sklearn.ensemble.RandomForestClassifier()
rf.fit(train_x, train_y)
# Out:
# [[0.05555556 0.         0.         0.02777778]
#  [0.03030303 0.         0.         0.03030303]
#  [0.15555556 0.04444444 0.         0.        ]
#  ...
#  [0.03773585 0.03773585 0.         0.        ]
#  [0.06521739 0.         0.         0.        ]
#  [0.125      0.         0.         0.        ]]
# ['cute' 'cute' 'cute' ... 'passion' 'passion' 'passion']
# 2857 2857
# C:\Users\yota-\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
accuracy = rf.score(test_x, test_y)
print('accuracy {0:.2%}'.format(accuracy))
# Out:
# accuracy 51.22%

# %%
predictions = rf.predict(densities)
#3次元プロットするためのモジュール
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook
#グラフの枠を作っていく
fig = plt.figure()
ax = Axes3D(fig)
#軸にラベルを付けたいときは書く
ax.set_xlabel(feature_words[0])
ax.set_ylabel(feature_words[1])
ax.set_zlabel(feature_words[2])
densities_pred = {}
for type_temp in types:
    densities_pred[type_temp] = []
    for i in range(len(predictions)):
        if predictions[i] == type_temp:
            densities_pred[type_temp].append(np.array(densities[i]))
    densities_pred[type_temp] = np.array(densities_pred[type_temp])
#print(densities_pred)
for type_temp in types:
    ax.plot(densities_pred[type_temp][:,0],densities_pred[type_temp][:,1],densities_pred[type_temp][:,2],marker = "o",color = colors[type_temp],label = type_temp,linestyle = "None",ms = 4)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
print(predictions)
print(densities)
# Out:
# ['cute' 'cute' 'cute' ... 'passion' 'passion' 'passion']
# [[0.05555556 0.         0.02777778]
#  [0.03030303 0.         0.03030303]
#  [0.15555556 0.04444444 0.        ]
#  ...
#  [0.03773585 0.03773585 0.        ]
#  [0.06521739 0.         0.        ]
#  [0.125      0.         0.        ]]

# %%
print(test_y)
# Out:
# ['passion' 'passion' 'cute' 'passion' 'cute' 'cool' 'cute' 'cute'
#  'passion' 'passion' 'cute' 'cute' 'passion' 'cute' 'cool' 'cute'
#  'passion' 'cool' 'cool' 'passion' 'passion' 'passion' 'cool' 'passion'
#  'passion' 'passion' 'cool' 'passion' 'cute' 'cute' 'cool' 'cool' 'cool'
#  'cool' 'passion' 'cute' 'cool' 'cute' 'passion' 'cool' 'cute' 'cute'
#  'cool' 'passion' 'cute' 'passion' 'passion' 'cool' 'cool' 'cool' 'cool'
#  'passion' 'passion' 'cool' 'passion' 'cool' 'cool' 'cute' 'passion'
#  'cute' 'cool' 'passion' 'cool' 'cool' 'cute' 'cool' 'cool' 'cool' 'cute'
#  'passion' 'passion' 'passion' 'cute' 'cool' 'cool' 'passion' 'passion'
#  'passion' 'cool' 'cute' 'passion' 'cool' 'passion' 'cute' 'cute'
#  'passion' 'passion' 'cool' 'passion' 'passion' 'cool' 'cool' 'cute'
#  'cute' 'cool' 'cool' 'cool' 'cute' 'passion' 'cool' 'passion' 'passion'
#  'cool' 'cute' 'cool' 'cute' 'passion' 'cute' 'cute' 'cute' 'passion'
#  'passion' 'passion' 'passion' 'cool' 'passion' 'cute' 'passion' 'cool'
#  'cute' 'cool' 'passion' 'cute' 'cute' 'cool' 'cool' 'cute' 'passion'
#  'cute' 'cool' 'cute' 'passion' 'cute' 'cool' 'passion' 'cool' 'cool'
#  'cute' 'passion' 'cool' 'cute' 'cool' 'cute' 'passion' 'cute' 'cute'
#  'cool' 'cool' 'cool' 'cool' 'cute' 'cool' 'cool' 'cute' 'cool' 'cute'
#  'cute' 'cute' 'cute' 'passion' 'cool' 'cute' 'cool' 'passion' 'passion'
#  'passion' 'passion' 'cute' 'cute' 'cute' 'cool' 'cute' 'cool' 'passion'
#  'cool' 'cute' 'cool' 'cool' 'passion' 'passion' 'cute' 'cute' 'cute'
#  'cute' 'cute' 'cute' 'passion' 'cool' 'cute' 'cute' 'cool' 'passion'
#  'passion' 'cute' 'passion' 'passion' 'passion' 'cute' 'cute' 'passion'
#  'passion' 'cool' 'cool' 'cool' 'cute' 'passion' 'cool' 'cool' 'passion'
#  'cool' 'passion' 'cool' 'cool' 'passion' 'cute' 'cute' 'cute' 'passion'
#  'cool' 'cute' 'passion' 'passion' 'passion' 'cool' 'cute' 'cute'
#  'passion' 'cute' 'cool' 'cool' 'cool' 'cool' 'passion' 'passion' 'cool'
#  'passion' 'cute' 'cute' 'cool' 'passion' 'cute' 'passion' 'cool' 'cool'
#  'passion' 'passion' 'cute' 'cute' 'cool' 'cool' 'cute' 'cool' 'cool'
#  'cool' 'cool' 'cool' 'passion' 'passion' 'passion' 'cute' 'cool' 'cute'
#  'passion' 'passion' 'cute' 'cool' 'passion' 'cool' 'cute' 'passion'
#  'passion' 'cool' 'passion' 'cute' 'passion' 'cool' 'cute' 'passion'
#  'passion' 'passion' 'cool' 'cute' 'passion' 'cute' 'cool' 'passion'
#  'cute' 'cool' 'cute' 'passion' 'cool' 'passion' 'cool' 'cool' 'passion'
#  'passion' 'passion' 'passion' 'passion' 'cute' 'cool' 'passion' 'cute'
#  'cool' 'passion' 'cute' 'cute' 'cool' 'passion' 'passion' 'passion'
#  'cute' 'passion' 'cute' 'passion' 'passion' 'cool' 'cool' 'cool'
#  'passion' 'cute' 'cute' 'cool' 'cool' 'cool' 'cool' 'cool' 'cool'
#  'passion' 'cool' 'cute' 'cool' 'cool' 'passion' 'passion' 'cute' 'cute'
#  'cute' 'passion' 'passion' 'cute' 'cool' 'cool' 'cool' 'cool' 'cool'
#  'cute' 'cool' 'cool' 'cute' 'cool' 'cool' 'cute' 'cool' 'cool' 'cute'
#  'passion' 'passion' 'cool' 'cool' 'passion' 'passion' 'cool' 'cute'
#  'passion' 'passion' 'cute' 'passion' 'cool' 'passion' 'cute' 'passion'
#  'cute' 'cute' 'cute' 'cool' 'cool' 'passion' 'cool' 'cool' 'cute'
#  'passion' 'cool' 'cute' 'cute' 'passion' 'cute' 'cool' 'cute' 'passion'
#  'cute' 'passion' 'passion' 'cute' 'cool' 'cool' 'cute' 'cool' 'passion'
#  'passion' 'cute' 'cute' 'cute' 'cute' 'passion' 'cute' 'passion' 'cute'
#  'cool' 'cool' 'cool' 'cute' 'cute' 'passion' 'cute' 'cool' 'passion'
#  'cute' 'cool' 'cool' 'cool' 'passion' 'passion' 'passion' 'passion'
#  'cool' 'passion' 'cool' 'cute' 'cool' 'cute' 'passion' 'cool' 'passion'
#  'passion' 'passion' 'cute' 'passion' 'passion' 'cool' 'cute' 'passion'
#  'cute' 'cute' 'passion' 'cool' 'cute' 'cool' 'cool' 'cool' 'cool' 'cute'
#  'cute' 'cute' 'cute' 'cool' 'cute' 'cute' 'passion' 'passion' 'cool'
#  'cute' 'cool' 'passion' 'cool' 'cute' 'cool' 'passion' 'passion'
#  'passion' 'cute' 'passion' 'cute' 'cool' 'cute' 'cute' 'passion' 'cool'
#  'passion' 'cute' 'cool' 'passion' 'passion' 'passion' 'cool' 'cute'
#  'cool' 'passion' 'passion' 'cute' 'cool' 'cute' 'cute' 'cute' 'cool'
#  'cute' 'passion' 'passion' 'cool' 'passion' 'cool' 'cute' 'cute' 'cute'
#  'passion' 'passion' 'passion' 'cool' 'cool' 'passion' 'cute' 'cute'
#  'cool' 'cool' 'passion' 'cool' 'cute' 'cute' 'cute' 'cute' 'cool' 'cute'
#  'cool' 'passion' 'cool' 'passion' 'passion' 'cute' 'passion' 'cute'
#  'cool' 'cool' 'cute' 'passion' 'cool' 'passion' 'passion' 'cool'
#  'passion' 'cute' 'passion' 'passion' 'cute' 'passion' 'passion' 'passion'
#  'cute' 'cute' 'passion' 'cool' 'cool' 'passion' 'passion' 'cool' 'cool'
#  'passion' 'cute' 'cute' 'cute' 'cute' 'cool' 'cool' 'cute' 'passion'
#  'cute' 'cute' 'cool' 'cute' 'cool' 'passion' 'passion' 'passion']
